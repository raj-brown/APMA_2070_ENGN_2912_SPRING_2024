# %% [markdown]
# ## Lecture 7b : Symbolic Regression

# %% [markdown]
# ## Table of Contents
# #### 1. [Function Approximation](#1-Function-Approximation)
# #### 2. [PK Model with no noise](#2-PK-Model-with-no-noise)
# #### 3. [PK Model with noise](#3-PK-Model-with-noise)

# %% [markdown]
# ## 1-Function Approximation

# %%
import numpy as np
from pysr import PySRRegressor 
from  numpy import cos as cos
from numpy import sin as sin

np.random.seed(1234)


x = 1.8 * np.random.randn(100, 5)
y = 6.53829874 * cos(x[:, 3]) + x[:, 0] ** 2 - 0.5

model = PySRRegressor(
    niterations=40,
    binary_operators = ["*", "+"],
    unary_operators = ["cos", 
                       "exp", 
                       "sin",
                       "inv(x) = 1/x", #"Julia Sntax"
                      ], 
    extra_sympy_mappings = {"inv": lambda x: 1/x},
    loss="loss(prediction, target) = (prediction - target)^2")

model.fit(x, y)
# Out:
# /usr/local/lib/python3.9/site-packages/pysr/sr.py:1296: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 2.460e+05
# Head worker occupation: 8.0%
# Progress: 548 / 600 total iterations (91.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.705e+01  1.028e-07  3.514003
# 3           2.012e+01  3.053e-01  (x0 * x0)
# 4           1.736e+01  1.479e-01  (cos(x3) * 8.009178)
# 6           1.415e+01  1.023e-01  ((7.1499686 * cos(x3)) + 1.8918728)
# 7           1.318e+01  7.086e-02  ((x0 * x0) + exp(cos(x3)))
# 8           2.242e-01  4.074e+00  ((x0 * x0) + (cos(x3) * 6.311219))
# 10          2.430e-13  1.151e+01  (((x0 * x0) + -0.5) + (cos(x3) * 6.5382986))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick      score                                      equation  \
# 	0         0.000000                                      3.514003
# 	1         0.305251                                     (x0 * x0)
# 	2         0.147924                          (cos(x3) * 8.009178)
# 	3         0.002633                     (sin(cos(x3)) * 9.078539)
# 	4         0.201883           ((7.1499686 * cos(x3)) + 1.8918728)
# 	5         0.070864                    ((x0 * x0) + exp(cos(x3)))
# 	6         4.073615            ((x0 * x0) + (cos(x3) * 6.311219))
# 	7  >>>>  13.775278  (((x0 * x0) + -0.5) + (cos(x3) * 6.5382986))
#
# 	           loss  complexity
# 	0  3.705405e+01           1
# 	1  2.012325e+01           3
# 	2  1.735624e+01           4
# 	3  1.731060e+01           5
# 	4  1.414606e+01           6
# 	5  1.317830e+01           7
# 	6  2.242389e-01           8
# 	7  2.430284e-13          10
# ]

# %%
model.sympy()
# Out:
# x0**2 + 6.5382986*cos(x3) - 0.49999994

# %%
print(model)
# Out:
# PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                          3.5130649
# 	1         0.305251                                          (x0 * x0)
# 	2         0.147924                               (8.009075 * cos(x3))
# 	3         0.002633                          (9.078012 * sin(cos(x3)))
# 	4         0.201883                ((7.1501555 * cos(x3)) + 1.8917109)
# 	5         0.070864                         ((x0 * x0) + exp(cos(x3)))
# 	6         4.073615                 ((x0 * x0) + (cos(x3) * 6.311219))
# 	7  >>>>  13.767859  (((x0 * x0) + (cos(x3) * 6.5382986)) + -0.4999...
# 	8         0.005357  ((x0 * (x0 * 1.0)) + ((cos(x3) * 6.5382986) + ...
# 	9         0.002550  ((((x0 * x0) + (cos(x3) * 6.5382986)) + ((cos(...
#
# 	           loss  complexity
# 	0  3.705405e+01           1
# 	1  2.012325e+01           3
# 	2  1.735624e+01           4
# 	3  1.731060e+01           5
# 	4  1.414606e+01           6
# 	5  1.317830e+01           7
# 	6  2.242389e-01           8
# 	7  2.466610e-13          10
# 	8  2.440326e-13          12
# 	9  2.409412e-13          17
# ]

# %% [markdown]
# ## 2-PK Model with no noise

# %%
import pysr
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
import csv


## Data Import
G = []
B = []
f = []
t = []
U = []
with open('data_PINN.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        G.append(float(row[1]))
        B.append(float(row[2]))
        U.append(float(row[3]))
        f.append(float(row[4]))
        t.append(float(row[0]))
        line_count += 1
    print(f'Processed {line_count} lines.')

G = np.array(G).reshape(-1,1)
B = np.array(B).reshape(-1,1)
f = np.array(f).reshape(-1,1)
t = np.array(t).reshape(-1,1)
d = np.concatenate((G, B, f), axis=1)
y = d[:, 2]
X = d[:, 0:2]


pysr_params = dict(
    populations=100,
    model_selection="best",
)


model = PySRRegressor(
    niterations=50,
    binary_operators=["plus", "mult"],
    **pysr_params
)

# Run model:
model.fit(X, y)

# reload Model
#model = PySRRegressor.from_file("hall_of_fame_2023-09-15_120648.996.pkl")

y_pred = model.predict(X)
err = np.square(np.subtract(y,y_pred)).mean()
print(f"Projection Error: {err}")
print(f"Model: {model}")

print(f"Model SymPy: {model.sympy(3)}")

#model.sympy(2)
print(f"Latex Equation: {model.latex(3)}")
# Out:
# Processed 1 lines.
# Processed 2 lines.
# Processed 3 lines.
# Processed 4 lines.
# Processed 5 lines.
# Processed 6 lines.
# Processed 7 lines.
# Processed 8 lines.
# Processed 9 lines.
# Processed 10 lines.
# Processed 11 lines.
# Processed 12 lines.
# Processed 13 lines.
# Processed 14 lines.
# Processed 15 lines.
# Processed 16 lines.
# Processed 17 lines.
# Processed 18 lines.
# Processed 19 lines.
# Processed 20 lines.
# Processed 21 lines.
# Processed 22 lines.
# Processed 23 lines.
# Processed 24 lines.
# Processed 25 lines.
# Processed 26 lines.
# Processed 27 lines.
# Processed 28 lines.
# Processed 29 lines.
# Processed 30 lines.
# Processed 31 lines.
# Processed 32 lines.
# Processed 33 lines.
# Processed 34 lines.
# Processed 35 lines.
# Processed 36 lines.
# Processed 37 lines.
# Processed 38 lines.
# Processed 39 lines.
# Processed 40 lines.
# Processed 41 lines.
# Processed 42 lines.
# Processed 43 lines.
# Processed 44 lines.
# Processed 45 lines.
# Processed 46 lines.
# Processed 47 lines.
# Processed 48 lines.
# Processed 49 lines.
# Processed 50 lines.
# Processed 51 lines.
# Processed 52 lines.
# Processed 53 lines.
# Processed 54 lines.
# Processed 55 lines.
# Processed 56 lines.
# Processed 57 lines.
# Processed 58 lines.
# Processed 59 lines.
# Processed 60 lines.
# Processed 61 lines.
# Processed 62 lines.
# Processed 63 lines.
# Processed 64 lines.
# Processed 65 lines.
# Processed 66 lines.
# Processed 67 lines.
# Processed 68 lines.
# Processed 69 lines.
# Processed 70 lines.
# Processed 71 lines.
# Processed 72 lines.
# Processed 73 lines.
# Processed 74 lines.
# Processed 75 lines.
# Processed 76 lines.
# Processed 77 lines.
# Processed 78 lines.
# Processed 79 lines.
# Processed 80 lines.
# Processed 81 lines.
# Processed 82 lines.
# Processed 83 lines.
# Processed 84 lines.
# Processed 85 lines.
# Processed 86 lines.
# Processed 87 lines.
# Processed 88 lines.
# Processed 89 lines.
# Processed 90 lines.
# Processed 91 lines.
# Processed 92 lines.
# Processed 93 lines.
# Processed 94 lines.
# Processed 95 lines.
# Processed 96 lines.
# Processed 97 lines.
# Processed 98 lines.
# Processed 99 lines.
# Processed 100 lines.
# Processed 101 lines.
# Processed 102 lines.
# Processed 103 lines.
# Processed 104 lines.
# Processed 105 lines.
# Processed 106 lines.
# Processed 107 lines.
# Processed 108 lines.
# Processed 109 lines.
# Processed 110 lines.
# Processed 111 lines.
# Processed 112 lines.
# Processed 113 lines.
# Processed 114 lines.
# Processed 115 lines.
# Processed 116 lines.
# Processed 117 lines.
# Processed 118 lines.
# Processed 119 lines.
# Processed 120 lines.
# Processed 121 lines.
# Processed 122 lines.
# Processed 123 lines.
# Processed 124 lines.
# Processed 125 lines.
# Processed 126 lines.
# Processed 127 lines.
# Processed 128 lines.
# Processed 129 lines.
# Processed 130 lines.
# Processed 131 lines.
# Processed 132 lines.
# Processed 133 lines.
# Processed 134 lines.
# Processed 135 lines.
# Processed 136 lines.
# Processed 137 lines.
# Processed 138 lines.
# Processed 139 lines.
# Processed 140 lines.
# Processed 141 lines.
# Processed 142 lines.
# Processed 143 lines.
# Processed 144 lines.
# Processed 145 lines.
# Processed 146 lines.
# Processed 147 lines.
# Processed 148 lines.
# Processed 149 lines.
# Processed 150 lines.
# Processed 151 lines.
# Processed 152 lines.
# Processed 153 lines.
# Processed 154 lines.
# Processed 155 lines.
# Processed 156 lines.
# Processed 157 lines.
# Processed 158 lines.
# Processed 159 lines.
# Processed 160 lines.
# Processed 161 lines.
# Processed 162 lines.
# Processed 163 lines.
# Processed 164 lines.
# Processed 165 lines.
# Processed 166 lines.
# Processed 167 lines.
# Processed 168 lines.
# Processed 169 lines.
# Processed 170 lines.
# Processed 171 lines.
# Processed 172 lines.
# Processed 173 lines.
# Processed 174 lines.
# Processed 175 lines.
# Processed 176 lines.
# Processed 177 lines.
# Processed 178 lines.
# Processed 179 lines.
# Processed 180 lines.
# Processed 181 lines.
# Processed 182 lines.
# Processed 183 lines.
# Processed 184 lines.
# Processed 185 lines.
# Processed 186 lines.
# Processed 187 lines.
# Processed 188 lines.
# Processed 189 lines.
# Processed 190 lines.
# Processed 191 lines.
# Processed 192 lines.
# Processed 193 lines.
# Processed 194 lines.
# Processed 195 lines.
# Processed 196 lines.
# Processed 197 lines.
# Processed 198 lines.
# Processed 199 lines.
# Processed 200 lines.
# Processed 201 lines.
# Processed 202 lines.
# Processed 203 lines.
# Processed 204 lines.
# Processed 205 lines.
# Processed 206 lines.
# Processed 207 lines.
# Processed 208 lines.
# Processed 209 lines.
# Processed 210 lines.
# Processed 211 lines.
# Processed 212 lines.
# Processed 213 lines.
# Processed 214 lines.
# Processed 215 lines.
# Processed 216 lines.
# Processed 217 lines.
# Processed 218 lines.
# Processed 219 lines.
# Processed 220 lines.
# Processed 221 lines.
# Processed 222 lines.
# Processed 223 lines.
# Processed 224 lines.
# Processed 225 lines.
# Processed 226 lines.
# Processed 227 lines.
# Processed 228 lines.
# Processed 229 lines.
# Processed 230 lines.
# Processed 231 lines.
# Processed 232 lines.
# Processed 233 lines.
# Processed 234 lines.
# Processed 235 lines.
# Processed 236 lines.
# Processed 237 lines.
# Processed 238 lines.
# Processed 239 lines.
# Processed 240 lines.
# Processed 241 lines.
# Processed 242 lines.
# Processed 243 lines.
# Processed 244 lines.
# Processed 245 lines.
# Processed 246 lines.
# Processed 247 lines.
# Processed 248 lines.
# Processed 249 lines.
# Processed 250 lines.
# Processed 251 lines.
# Processed 252 lines.
# Processed 253 lines.
# Processed 254 lines.
# Processed 255 lines.
# Processed 256 lines.
# Processed 257 lines.
# Processed 258 lines.
# Processed 259 lines.
# Processed 260 lines.
# Processed 261 lines.
# Processed 262 lines.
# Processed 263 lines.
# Processed 264 lines.
# Processed 265 lines.
# Processed 266 lines.
# Processed 267 lines.
# Processed 268 lines.
# Processed 269 lines.
# Processed 270 lines.
# Processed 271 lines.
# Processed 272 lines.
# Processed 273 lines.
# Processed 274 lines.
# Processed 275 lines.
# Processed 276 lines.
# Processed 277 lines.
# Processed 278 lines.
# Processed 279 lines.
# Processed 280 lines.
# Processed 281 lines.
# Processed 282 lines.
# Processed 283 lines.
# Processed 284 lines.
# Processed 285 lines.
# Processed 286 lines.
# Processed 287 lines.
# Processed 288 lines.
# Processed 289 lines.
# Processed 290 lines.
# Processed 291 lines.
# Processed 292 lines.
# Processed 293 lines.
# Processed 294 lines.
# Processed 295 lines.
# Processed 296 lines.
# Processed 297 lines.
# Processed 298 lines.
# Processed 299 lines.
# Processed 300 lines.
# Processed 301 lines.
# Processed 302 lines.
# Processed 303 lines.
# Processed 304 lines.
# Processed 305 lines.
# Processed 306 lines.
# Processed 307 lines.
# Processed 308 lines.
# Processed 309 lines.
# Processed 310 lines.
# Processed 311 lines.
# Processed 312 lines.
# Processed 313 lines.
# Processed 314 lines.
# Processed 315 lines.
# Processed 316 lines.
# Processed 317 lines.
# Processed 318 lines.
# Processed 319 lines.
# Processed 320 lines.
# Processed 321 lines.
# Processed 322 lines.
# Processed 323 lines.
# Processed 324 lines.
# Processed 325 lines.
# Processed 326 lines.
# Processed 327 lines.
# Processed 328 lines.
# Processed 329 lines.
# Processed 330 lines.
# Processed 331 lines.
# Processed 332 lines.
# Processed 333 lines.
# Processed 334 lines.
# Processed 335 lines.
# Processed 336 lines.
# Processed 337 lines.
# Processed 338 lines.
# Processed 339 lines.
# Processed 340 lines.
# Processed 341 lines.
# Processed 342 lines.
# Processed 343 lines.
# Processed 344 lines.
# Processed 345 lines.
# Processed 346 lines.
# Processed 347 lines.
# Processed 348 lines.
# Processed 349 lines.
# Processed 350 lines.
# Processed 351 lines.
# Processed 352 lines.
# Processed 353 lines.
# Processed 354 lines.
# Processed 355 lines.
# Processed 356 lines.
# Processed 357 lines.
# Processed 358 lines.
# Processed 359 lines.
# Processed 360 lines.
# Processed 361 lines.
# Processed 362 lines.
# Processed 363 lines.
# Processed 364 lines.
# Processed 365 lines.
# Processed 366 lines.
# Processed 367 lines.
# Processed 368 lines.
# Processed 369 lines.
# Processed 370 lines.
# Processed 371 lines.
# Processed 372 lines.
# Processed 373 lines.
# Processed 374 lines.
# Processed 375 lines.
# Processed 376 lines.
# Processed 377 lines.
# Processed 378 lines.
# Processed 379 lines.
# Processed 380 lines.
# Processed 381 lines.
# Processed 382 lines.
# Processed 383 lines.
# Processed 384 lines.
# Processed 385 lines.
# Processed 386 lines.
# Processed 387 lines.
# Processed 388 lines.
# Processed 389 lines.
# Processed 390 lines.
# Processed 391 lines.
# Processed 392 lines.
# Processed 393 lines.
# Processed 394 lines.
# Processed 395 lines.
# Processed 396 lines.
# Processed 397 lines.
# Processed 398 lines.
# Processed 399 lines.
# Processed 400 lines.
# Processed 401 lines.
# Processed 402 lines.
# Processed 403 lines.
# Processed 404 lines.
# Processed 405 lines.
# Processed 406 lines.
# Processed 407 lines.
# Processed 408 lines.
# Processed 409 lines.
# Processed 410 lines.
# Processed 411 lines.
# Processed 412 lines.
# Processed 413 lines.
# Processed 414 lines.
# Processed 415 lines.
# Processed 416 lines.
# Processed 417 lines.
# Processed 418 lines.
# Processed 419 lines.
# Processed 420 lines.
# Processed 421 lines.
# Processed 422 lines.
# Processed 423 lines.
# Processed 424 lines.
# Processed 425 lines.
# Processed 426 lines.
# Processed 427 lines.
# Processed 428 lines.
# Processed 429 lines.
# Processed 430 lines.
# Processed 431 lines.
# Processed 432 lines.
# Processed 433 lines.
# Processed 434 lines.
# Processed 435 lines.
# Processed 436 lines.
# Processed 437 lines.
# Processed 438 lines.
# Processed 439 lines.
# Processed 440 lines.
# Processed 441 lines.
# Processed 442 lines.
# Processed 443 lines.
# Processed 444 lines.
# Processed 445 lines.
# Processed 446 lines.
# Processed 447 lines.
# Processed 448 lines.
# Processed 449 lines.
# Processed 450 lines.
# Processed 451 lines.
# Processed 452 lines.
# Processed 453 lines.
# Processed 454 lines.
# Processed 455 lines.
# Processed 456 lines.
# Processed 457 lines.
# Processed 458 lines.
# Processed 459 lines.
# Processed 460 lines.
# Processed 461 lines.
# Processed 462 lines.
# Processed 463 lines.
# Processed 464 lines.
# Processed 465 lines.
# Processed 466 lines.
# Processed 467 lines.
# Processed 468 lines.
# Processed 469 lines.
# Processed 470 lines.
# Processed 471 lines.
# Processed 472 lines.
# Processed 473 lines.
# Processed 474 lines.
# Processed 475 lines.
# Processed 476 lines.
# Processed 477 lines.
# Processed 478 lines.
# Processed 479 lines.
# Processed 480 lines.
# Processed 481 lines.
# Processed 482 lines.
# Processed 483 lines.
# Processed 484 lines.
# Processed 485 lines.
# Processed 486 lines.
# Processed 487 lines.
# Processed 488 lines.
# Processed 489 lines.
# Processed 490 lines.
# Processed 491 lines.
# Processed 492 lines.
# Processed 493 lines.
# Processed 494 lines.
# Processed 495 lines.
# Processed 496 lines.
# Processed 497 lines.
# Processed 498 lines.
# Processed 499 lines.
# Processed 500 lines.
# Processed 501 lines.
# /usr/local/lib/python3.9/site-packages/pysr/sr.py:1296: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 2.140e+05
# Head worker occupation: 7.5%
# Progress: 492 / 5000 total iterations (9.840%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.6304787) + -0.0016880715)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.020e+05
# Head worker occupation: 7.5%
# Progress: 965 / 5000 total iterations (19.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.6304787) + -0.0016880715)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# 13          2.594e-08  2.760e-02  ((x0 + (x1 * (-0.22024068 + (x0 + (0.16714305 * x0))))) * 0.68...
#                                   761677)
# 15          2.011e-08  1.272e-01  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * -0.4076103) + x...
#                                   0))))) * 0.68761677)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.120e+05
# Head worker occupation: 7.3%
# Progress: 1486 / 5000 total iterations (29.720%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.6304787) + -0.0016880715)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# 11          2.127e-08  1.544e-01  ((x0 + (x1 * (-0.568683 * 0.37097508))) * (0.68761677 + x1))
# 15          2.011e-08  1.402e-02  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * -0.4076103) + x...
#                                   0))))) * 0.68761677)
# 17          1.952e-08  1.489e-02  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * (-0.4076103 + x...
#                                   0)) + x0))))) * 0.68761677)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+05
# Head worker occupation: 7.4%
# Progress: 1924 / 5000 total iterations (38.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.6304787) + -0.0016880715)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# 11          2.127e-08  1.544e-01  ((x0 + (x1 * (-0.568683 * 0.37097508))) * (0.68761677 + x1))
# 15          1.974e-08  1.867e-02  ((x0 + (x1 * (((1.6753387 * -0.2654747) + 0.06626245) * 0.5429...
#                                   983))) * (0.68761677 + x1))
# 17          1.952e-08  5.581e-03  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * (-0.4076103 + x...
#                                   0)) + x0))))) * 0.68761677)
# 19          1.937e-08  3.820e-03  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * (-0.4076103 + (...
#                                   x0 + x0))) + x0))))) * 0.68761677)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+05
# Head worker occupation: 7.2%
# Progress: 2384 / 5000 total iterations (47.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.63047516) + -0.0016881406)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# 11          2.127e-08  1.544e-01  ((x0 + (x1 * (-0.568683 * 0.37097508))) * (0.68761677 + x1))
# 15          1.974e-08  1.867e-02  ((x0 + (x1 * (((1.6753387 * -0.2654747) + 0.06626245) * 0.5429...
#                                   983))) * (0.68761677 + x1))
# 17          1.952e-08  5.581e-03  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * (-0.4076103 + x...
#                                   0)) + x0))))) * 0.68761677)
# 19          1.937e-08  3.820e-03  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * (-0.4076103 + (...
#                                   x0 + x0))) + x0))))) * 0.68761677)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.010e+05
# Head worker occupation: 6.9%
# Progress: 2784 / 5000 total iterations (55.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.63047516) + -0.0016881406)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# 11          2.127e-08  1.544e-01  ((x0 + (x1 * (-0.568683 * 0.37097508))) * (0.68761677 + x1))
# 15          1.974e-08  1.867e-02  ((x0 + (x1 * (((1.6753387 * -0.2654747) + 0.06626245) * 0.5429...
#                                   983))) * (0.68761677 + x1))
# 17          1.952e-08  5.581e-03  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * (-0.4076103 + x...
#                                   0)) + x0))))) * 0.68761677)
# 19          1.937e-08  3.820e-03  ((x0 + (x1 * (-0.568683 + (0.37097508 + ((x1 * (-0.4076103 + (...
#                                   x0 + x0))) + x0))))) * 0.68761677)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.930e+05
# Head worker occupation: 6.9%
# Progress: 3241 / 5000 total iterations (64.820%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.63047516) + -0.0016881406)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# 11          1.822e-08  2.317e-01  ((x0 + ((1.07841 * -0.1926676) * x1)) * (0.68747646 + x1))
# 17          1.643e-08  1.728e-02  ((x0 + (x1 * ((((1.6753387 + x0) * -0.2654747) + 0.06626245) *...
#                                    0.5429983))) * (0.68761677 + x1))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+05
# Head worker occupation: 7.5%
# Progress: 3774 / 5000 total iterations (75.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.63047516) + -0.0016881406)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.897e-08  1.745e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68761677)
# 11          1.822e-08  2.317e-01  ((x0 + ((1.07841 * -0.1926676) * x1)) * (0.68747646 + x1))
# 17          1.643e-08  1.728e-02  ((x0 + (x1 * ((((1.6753387 + x0) * -0.2654747) + 0.06626245) *...
#                                    0.5429983))) * (0.68761677 + x1))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.060e+05
# Head worker occupation: 7.9%
# Progress: 4248 / 5000 total iterations (84.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.63047516) + -0.0016881406)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.712e-08  2.075e-01  ((x0 + (x1 * (-0.22024068 + x0))) * 0.68871695)
# 11          1.822e-08  1.988e-01  ((x0 + ((1.07841 * -0.1926676) * x1)) * (0.68747646 + x1))
# 17          1.643e-08  1.728e-02  ((x0 + (x1 * ((((1.6753387 + x0) * -0.2654747) + 0.06626245) *...
#                                    0.5429983))) * (0.68761677 + x1))
# 19          1.619e-08  7.218e-03  (((x0 + (x1 * ((((1.6753387 + x0) * -0.2654747) + 0.06626245) ...
#                                   * 0.5429983))) * (0.68761677 + x1)) * 1.000663)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.060e+05
# Head worker occupation: 7.6%
# Progress: 4658 / 5000 total iterations (93.160%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.422e-05  6.215e-01  x0
# 3           1.006e-05  6.123e-01  (x0 * 0.5984119)
# 5           7.361e-06  1.560e-01  ((x0 * 0.63047516) + -0.0016881406)
# 7           4.107e-08  2.594e+00  (((-0.20763305 * x1) + x0) * 0.7048448)
# 9           2.142e-08  3.254e-01  ((x0 + (-0.20450477 * x1)) * (0.68761677 + x1))
# 11          1.822e-08  8.081e-02  ((x0 + ((1.07841 * -0.1926676) * x1)) * (0.68747646 + x1))
# 17          1.635e-08  1.814e-02  ((x0 + (x1 * ((((1.373169 + x0) * -0.2654747) + 0.06626245) * ...
#                                   0.68761677))) * (0.68761677 + x1))
# 19          1.619e-08  4.633e-03  (((x0 + (x1 * ((((1.6753387 + x0) * -0.2654747) + 0.06626245) ...
#                                   * 0.5429983))) * (0.68761677 + x1)) * 1.000663)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# Projection Error: 2.1421360165755553e-08
# Model: PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                                 x0
# 	1        0.612332                                   (x0 * 0.5984119)
# 	2        0.156018                ((x0 * 0.63047516) + -0.0016881406)
# 	3        2.594365            (((-0.20763305 * x1) + x0) * 0.7048448)
# 	4  >>>>  0.325425    ((x0 + (-0.20450477 * x1)) * (0.68761677 + x1))
# 	5        0.080812  ((x0 + ((1.07841 * -0.1926676) * x1)) * (0.687...
# 	6        0.018908  ((x0 + (x1 * ((((1.373169 + x0) * -0.2654747) ...
# 	7        0.002328  (((x0 + (x1 * ((((1.6753387 + x0) * -0.2654747...
#
# 	           loss  complexity
# 	0  3.422341e-05           1
# 	1  1.005677e-05           3
# 	2  7.361108e-06           5
# 	3  4.106830e-08           7
# 	4  2.142133e-08           9
# 	5  1.822443e-08          11
# 	6  1.626991e-08          17
# 	7  1.619432e-08          19
# ]
# Model SymPy: 0.7048448*x0 - 0.14634907560064*x1
# Latex Equation: 0.705 x_{0} - 0.146 x_{1}

# %% [markdown]
# ## 3-PK Model with noise

# %%
import pysr
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
import csv
import sys
import matplotlib.pyplot as plt

## Data Import
G = []
B = []
f = []
t = []


weights = (1/np.sqrt( 0.01)) * np.ones((501,))


with open('pred_500_0.01.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        G.append(float(row[1]))
        B.append(float(row[2]))
        f.append(float(row[4]))
        t.append(float(row[0]))
    line_count += 1
    print(f'Processed {line_count} lines.')

G = np.array(G).reshape(-1,1)
B = np.array(B).reshape(-1,1)
f = np.array(f).reshape(-1,1)
t = np.array(t).reshape(-1,1)
d = np.concatenate((G, B, f), axis=1)
y = d[:, 2]
X = d[:, 0:2]


pysr_params = dict(
    populations=50,
    procs = 8,
    ncyclesperiteration=2,
    population_size=30,
    model_selection="best",
    loss="myloss(x, y, w) = w * abs(x - y)",
    binary_operators=["plus", "sub", "mult"],
    maxsize=9,               
)

model = PySRRegressor(
    niterations=50,
    **pysr_params
)

# Run model:
#model = PySRRegressor.from_file("hall_of_fame_2024-01-17_155335.906.pkl")
model.fit(X, y, weights=weights)
y_pred = model.predict(X)
err = np.square(np.subtract(y,y_pred)).mean()

best_idx = model.equations_.query(
    f"loss < {2 * model.equations_.loss.min()}"
).score.idxmax()


print(f"Best model:", model.sympy(best_idx))

print(f"Projection Error: {err}")
print(f"Model: {model}")

print(f"Model SymPy: {model.sympy()}")

#print("4 model:", model.sympy(5))
print(f"Latex Equation: {model.latex()}")
# Out:
# Processed 1 lines.
# /usr/local/lib/python3.9/site-packages/pysr/sr.py:1296: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 8} will be ignored.
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 6.650e+04
# Head worker occupation: 19.1%
# Progress: 1474 / 2500 total iterations (58.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.650e-03  4.608e-02  -0.00023209452
# 3           1.982e-03  1.454e-01  (0.58497137 * x0)
# 5           8.474e-04  4.247e-01  ((x1 * -0.16856305) + x0)
# 7           1.029e-04  1.054e+00  ((x1 * -0.15540284) + (x0 * 0.72154945))
# 9           5.141e-05  3.469e-01  ((x1 * -0.15254046) + ((x0 * 0.7219004) + -9.102005e-5))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# Best model: 0.72168493*x0 - 0.15253511*x1 - 8.902654e-5
# Projection Error: 3.2777034856381267e-08
# Model: PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                     -0.00023209452
# 	1        0.145443                                  (0.58497137 * x0)
# 	2        0.424730                          ((x1 * -0.16856305) + x0)
# 	3        1.054245           ((x1 * -0.15540284) + (x0 * 0.72154945))
# 	4  >>>>  0.348508  ((x1 * -0.15253511) + ((x0 * 0.72168493) + -8....
#
# 	       loss  complexity
# 	0  0.002650           1
# 	1  0.001982           3
# 	2  0.000847           5
# 	3  0.000103           7
# 	4  0.000051           9
# ]
# Model SymPy: 0.72168493*x0 - 0.15253511*x1 - 8.902654e-5
# Latex Equation: 0.722 x_{0} - 0.153 x_{1} - 8.90 \cdot 10^{-5}
